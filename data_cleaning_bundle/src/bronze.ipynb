# %%
# %sql
CREATE OR REPLACE TABLE datacleaning.bronze.events
AS
SELECT *
FROM read_files(
    '/Volumes/datacleaning/bronze/ecommerce/events.csv',
    format => 'csv',
    header => true
);

# %%
# %sql
CREATE OR REPLACE TABLE datacleaning.bronze.order_items
AS
SELECT *
FROM read_files(
    '/Volumes/datacleaning/bronze/ecommerce/order_items.csv',
    format => 'csv',
    header => true
);

# %%
# %sql
CREATE OR REPLACE TABLE datacleaning.bronze.orders
AS
SELECT *
FROM read_files(
    '/Volumes/datacleaning/bronze/ecommerce/orders.csv',
    format => 'csv',
    header => true
);

# %%
# %sql
CREATE OR REPLACE TABLE datacleaning.bronze.products
AS
SELECT *
FROM read_files(
    '/Volumes/datacleaning/bronze/ecommerce/products.csv',
    format => 'csv',
    header => true
);

# %%
# %sql
CREATE OR REPLACE TABLE datacleaning.bronze.reviews
AS
SELECT *
FROM read_files(
    '/Volumes/datacleaning/bronze/ecommerce/reviews.csv',
    format => 'csv',
    header => true
);

# %%
# %sql
CREATE OR REPLACE TABLE datacleaning.bronze.users
AS
SELECT *
FROM read_files(
    '/Volumes/datacleaning/bronze/ecommerce/users.csv',
    format => 'csv',
    header => true
);
